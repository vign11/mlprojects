# %%
from PIL import Image
import torch
import matplotlib.pyplot as plt

model2 = torch.hub.load("bryandlee/animegan2-pytorch:main", "generator", pretrained="face_paint_512_v2")
face2paint = torch.hub.load("bryandlee/animegan2-pytorch:main", "face2paint", size=512)

for inpimg in ['/content/suga2.jpg']:  
  img = Image.open(inpimg).convert("RGB")
  out = face2paint(model2, img)
  fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(8, 4))
  ax1.imshow(img)
  ax1.axis('off')
  ax2.imshow(out)
  ax2.axis('off')
  plt.show()
# Out:
# Using cache found in /root/.cache/torch/hub/bryandlee_animegan2-pytorch_main
# Using cache found in /root/.cache/torch/hub/bryandlee_animegan2-pytorch_main

# %%
from PIL import Image
import torch
import matplotlib.pyplot as plt

model2 = torch.hub.load("bryandlee/animegan2-pytorch:main", "generator", pretrained="face_paint_512_v2")
face2paint = torch.hub.load("bryandlee/animegan2-pytorch:main", "face2paint", size=512)

for inpimg in ['/content/suga3.jpg']:  
  img = Image.open(inpimg).convert("RGB")
  out = face2paint(model2, img)
  fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(8, 4))
  ax1.imshow(img)
  ax1.axis('off')
  ax2.imshow(out)
  ax2.axis('off')
  plt.show()
# Out:
# Using cache found in /root/.cache/torch/hub/bryandlee_animegan2-pytorch_main
# Using cache found in /root/.cache/torch/hub/bryandlee_animegan2-pytorch_main
